# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()

plt.subplot(1, 2, 1)

ld = np.array([1,2,3,4,5,6,7,8])

plt.plot(ld, '-o')

plt.subplot(1, 2, 2)

ed = ld**2

plt.plot(ed, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.subplot(1, 2, 1)
plt.plot(ed, '-x')
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.

# %%
plt.figure()

ax1 = plt.subplot(1, 2, 1)
plt.plot(ld, '-o')

ax2 = plt.subplot(1, 2, 2, sharey = ax1)
plt.plot(ed, '-x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3,3, sharex = True, sharey = True)

ax5.plot(ld, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for ax in plt.gcf().get_axes():
    ax.tick_params(labelbottom = True, labelleft = True)

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3,3, sharex = True, sharey = True)

ax5.plot(ld, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for ax in plt.gcf().get_axes():
    ax.tick_params(reset = True)
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %%
plt.gcf().canvas.draw()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex = True)

axs = [ax1, ax2, ax3, ax4]

for n in range(0, len(axs)):
    ss = 10**(n+1)
    s = np.random.normal(loc = 0, scale = 1, size = ss)
    axs[n].hist(s)
    axs[n].set_title('n{}'.format(ss))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2,2, sharex = True)
axs = [ax1, ax2, ax3, ax4]

for i in range(len(axs)):
    ss = 10**(i+1)
    s = np.random.normal(loc = 0, scale = 1, size =ss)
    axs[i].hist(s, bins = 100)
    axs[i].set_title('n = {}'.format(ss))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
y = np.random.normal(loc = 0, scale = 1, size = 1000)
x = np.random.random(size = 1000)

plt.scatter(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec

plt.figure()
gspec = gridspec.GridSpec(3,3)

th = plt.subplot(gspec[0, 1:])
sh = plt.subplot(gspec[1: , 0])
lr = plt.subplot(gspec[1:, 1:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y = np.random.normal(loc = 0, scale = 1, size = 1000)
x = np.random.random(size = 1000)

lr.clear()
lr.scatter(x, y)

th.clear()
th.hist(x, bins = 100, normed = True)

sh.clear()
s = sh.hist(y, bins = 100, orientation = 'horizontal', normed = True)
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:11: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   # This is added back by InteractiveShellApp.init_path()

# %%
sh.invert_xaxis()

# %%
for ax in [th, lr]:
    ax.set_xlim(0, 1)
for ax in [sh, lr]:
    ax.set_ylim(-5,5)

# %%
import pandas as pd

ns = np.random.normal(loc = 0, scale = 1, size = 10000)
rs = np.random.random(size = 10000)
gs = np.random.gamma(2, size = 10000)

df = pd.DataFrame({'normal' : ns, 'random' : rs, 'gamma' : gs})

# %%
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.011105      0.502536      1.994428
# std        0.998355      0.290649      1.423295
# min       -4.145958      0.000004      0.006044
# 25%       -0.684668      0.246936      0.949224
# 50%       -0.005316      0.502545      1.670093
# 75%        0.661434      0.752791      2.678383
# max        3.767564      0.999991     13.828702

# %%
plt.figure()

_ = plt.boxplot(df['normal'], whis = 'range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.clf()

_ = plt.boxplot([df['normal'], df['random'], df['gamma']], whis = 'range')

# %%
plt.figure()
_ = plt.hist(df['gamma'], bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()

_ = plt.hist(df['random'], bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis = 'range')

ax2 = mpl_il.inset_axes(plt.gca(), width = '60%', height = '40%', loc = 2)
ax2.hist(df['gamma'], bins = 100)
ax2.margins(x = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax2.yaxis.tick_right()

# %%
plt.figure()
_ = plt.boxplot([df['normal'], df['random'], df['gamma']])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()

y = np.random.normal(loc = 0, scale = 1, size = 10000)
x = np.random.random(size = 10000)

_ = plt.hist2d(x, y, bins = 25)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()

_ = plt.hist2d(x, y, bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.colorbar()

# %%
import matplotlib.animation as animation

n = 100
x = np.random.randn(n)

# %%
def update(curr):
    if curr == n: 
        a.event_source.stop()
    plt.cla()
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins=bins)
    plt.axis([-4,4,0,30])
    plt.annotate('n = {}'.format(curr), [3,27])

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">
