# %%
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('ggplot')

# %%
import numpy as np
import pandas as pd

np.random.seed(123)
x = np.array([1,2,3]).cumsum(0)
x
# Out:
# array([1, 3, 6], dtype=int32)

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'A': np.random.randn(365).cumsum(0),
                  'B' : np.random.randn(365).cumsum(0) + 20,
                  'C' : np.random.randn(365).cumsum(0) -20},
                  index = pd.date_range('1/1/2020', periods = 365))

df.head()
# Out:
#                    A          B          C
# 2020-01-01  2.261787  20.638129 -19.528413
# 2020-01-02  3.387227  20.991658 -20.347075
# 2020-01-03  3.446613  19.880180 -20.519080
# 2020-01-04  6.033622  18.936269 -20.022457
# 2020-01-05  5.397251  19.617007 -19.891695

# %%
df.plot();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
df.plot('A', 'B', kind = 'scatter')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
df.plot.scatter('A', 'B', c = 'C', s = df['C'], colormap = 'viridis')
# Out:
# <img src="data:image/png;base64,..." width="800">
# F:\Anaconda\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df.plot.box()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
df.plot.hist(alpha = 0.7)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
df.plot.kde()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
pd.plotting.scatter_matrix(iris);
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
pd.plotting.parallel_coordinates(iris, 'Name')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import seaborn as sns

# %%
np.random.seed(1234)
v1 = pd.Series(np.random.normal(0, 10, 1000), name = 'v1')
v2 = pd.Series(2*v1 + np.random.normal(60, 15, 1000), name = 'v2')

# %%
plt.figure()
plt.hist(v1, alpha = 0.7, bins = np.arange(-50,150,5), label = 'v1')
plt.hist(v2, alpha = 0.7, bins = np.arange(-50,150,5), label = 'v2')
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure()
plt.hist([v1, v2], histtype = 'barstacked', normed = True)
v3 = np.concatenate((v1,v2))
sns.kdeplot(v3);
# Out:
# <img src="data:image/png;base64,..." width="800">
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %%
plt.figure()
sns.distplot(v3, hist_kws = {'color': 'Teal'}, kde_kws = {'color': 'Navy'});
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sns.jointplot(v1,v2, kind = 'hex')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
grid = sns.jointplot(v1, v2)
grid.ax_joint.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.set_style('white')

sns.jointplot(v1, v2, kind = 'kde', space = 0)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.pairplot(iris, hue = 'Name', diag_kind = 'kde', size = 2)
# Out:
# F:\Anaconda\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <img src="data:image/png;base64,..." width="932">

# %%
plt.figure()
plt.subplot(121)
sns.swarmplot('Name', 'PetalLength', data = iris)
plt.subplot(122)
sns.violinplot('Name', 'PetalLength', data = iris)
# Out:
# <img src="data:image/png;base64,..." width="800">
